# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Youtube = [1,1,1,1,1,1]
Halloween = [2, np.nan, np.nan, np.nan, np.nan, np.nan]
Promotion = [3, np.nan, np.nan, np.nan, np.nan, np.nan]
Twitch = [4, 2, 2, 2, 2, 3]
Gacha = [5, 3, 8, 8, 8, 8]
Gen_Apprc = [6, 10, 3, 3, 9, 4]
Birthday = [7, 4, 6, np.nan, np.nan, np.nan]
Reddit = [8, 6, 4, 5, 5, 5]
Rare_Char = [9, 5, 5, 4, 4, 2]
Gag = [10, np.nan, np.nan, 9, np.nan, np.nan]
Char_Apprc = [np.nan, 8, 7, 6, 6, 6]
Gen_Stream = [np.nan, 7, 9, 7, 7, 7]
Video = [np.nan, np.nan, np.nan, np.nan, 10, 9]
Feat_Gacha = [np.nan, 9, 10, 10, 3, 10]

# %%
plt.figure(figsize=(15,8))

plt.plot(Youtube, 'r')

plt.plot(0,2, color = 'sandybrown', marker = 'o')

plt.plot(0,3, color = 'darkturquoise', marker = 'o')

plt.plot(Twitch, 'purple')

plt.plot(Gacha, 'gold')

plt.plot(Gen_Apprc, 'g')

plt.plot(Birthday,'firebrick')

plt.plot(Reddit, 'darkorange')

plt.plot(Rare_Char, 'dodgerblue')

plt.plot(0, 10, color = 'pink', marker = 'o')
plt.plot(3, 9, color = 'pink', marker = 'o')

plt.plot(Char_Apprc, 'magenta')

plt.plot(Gen_Stream, 'grey')

plt.plot(Video, 'black')

plt.plot(Feat_Gacha, 'b')


plt.gca().invert_yaxis()
plt.yticks(np.arange(1, 11, 1.0))
positions = (0, 1, 2, 3, 4, 5)
labels = ("11/3", "11/5", "11/7", "11/9", "11/10 Maintenance", "11/11 (Update 1.1)")
plt.xticks(positions, labels)
plt.gca().grid(True)
